# %% [markdown]
# REVOKE all Permisions

# %%
# %sql
REVOKE ALL PRIVILEGES ON CATALOG apple_production from `DataEnginers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  apple_production.bronze from `DataEnginers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  apple_production.silver from `DataEnginers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  apple_production.golden from `DataEnginers`;

# %%
# %sql
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-data` from `DataEnginers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` from `DataEnginers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` from `DataEnginers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` from `DataEnginers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` from `DataEnginers`;
