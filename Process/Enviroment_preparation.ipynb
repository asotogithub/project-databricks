# %% [markdown]
# ### POJECTO FINAL DE CURSO.

# %% [markdown]
# # Widgets

# %%
dbutils.widgets.removeAll();

# %%
# %sql
create widget text storageName default "adlssmartdatasvar0912";

# %% [markdown]
# # External location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-data`
URL 'abfss://data@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación de catalogos y tablas'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación de datasets csv'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-bronze`
URL 'abfss://bronze@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para tablas bronze'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-silver`
URL 'abfss://silver@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para tablas silver'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-golden`
URL 'abfss://golden@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para tablas golden'

# %% [markdown]
# # Catalogs and Schema

# %%
# %sql
CREATE CATALOG IF NOT EXISTS catalog_smartdata
MANAGED LOCATION 'abfss://data@${storageName}.dfs.core.windows.net/'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.raw;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.bronze;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.silver;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.golden;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.exploratory;

CREATE VOLUME IF NOT EXISTS catalog_smartdata.raw.datasets;

# %% [markdown]
# ### Share the golden schema to the Power BI Tool

# %%
# %sql
DROP SHARE IF EXISTS SALES_H2O_SHARE;
DROP RECIPIENT IF EXISTS ExternalCompanysConnect;

# %%
# %sql
DROP SHARE IF EXISTS VENTAS_SHARE;
--DROP RECIPIENT IF EXISTS ExternalCompanysConnect;

# %%
# %sql
CREATE SHARE SALES_H2O_SHARE

# %%
# %sql
ALTER SHARE SALES_H2O_SHARE 
ADD SCHEMA catalog_smartdata.golden

# %%
# %sql
CREATE RECIPIENT ExternalCompanysConnect

# %%
# %sql
GRANT SELECT 
ON SHARE SALES_H2O_SHARE
TO RECIPIENT ExternalCompanysConnect

# %% [markdown]
# ### Fin de la configuracion
